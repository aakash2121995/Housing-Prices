# %%
import pandas as pd
df = pd.read_csv("train.csv")
df.info()
# %matplotlib inline
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1461 entries, 0 to 1460
# Data columns (total 81 columns):
# Id               1461 non-null int64
# MSSubClass       1461 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1202 non-null float64
# LotArea          1461 non-null int64
# Street           1461 non-null object
# Alley            91 non-null object
# LotShape         1461 non-null object
# LandContour      1461 non-null object
# Utilities        1460 non-null object
# LotConfig        1461 non-null object
# LandSlope        1461 non-null object
# Neighborhood     1461 non-null object
# Condition1       1461 non-null object
# Condition2       1461 non-null object
# BldgType         1461 non-null object
# HouseStyle       1461 non-null object
# OverallQual      1461 non-null int64
# OverallCond      1461 non-null int64
# YearBuilt        1461 non-null int64
# YearRemodAdd     1461 non-null int64
# RoofStyle        1461 non-null object
# ...

# %%
import seaborn as sns

sns.pairplot(data = df[["SalePrice","YearBuilt","SaleCondition"]],size=5,hue='SaleCondition')

# %%
import seaborn as sns

sns.pairplot(data = df[["SalePrice","PoolArea","SaleCondition"]],size=5,hue='SaleCondition')

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1461.000000  1461.000000  1202.000000    1461.000000  1461.000000
# mean    730.191650    56.899384    70.060732   10516.477755     6.099932
# std     421.630362    42.286160    24.277513    9977.855091     1.382724
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.000000    20.000000    59.000000    7558.000000     5.000000
# 50%     730.000000    50.000000    69.500000    9480.000000     6.000000
# 75%    1095.000000    70.000000    80.000000   11600.000000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1461.000000  1461.000000   1461.000000  1453.000000  1461.000000
# mean      5.574949  1971.271732   1984.860370   103.819683   443.604381
# std       1.112520    30.192931     20.639361   181.076356   455.943868
# ...

# %%
sns.barplot(x="HouseStyle",y="SalePrice",data=df)

# %%
sns.barplot(x="LotConfig",y="SalePrice",data=df)

# %%
sns.barplot(x="OverallCond",y="SalePrice",data=df)

# %%
sns.barplot(x="OverallQual",y="SalePrice",data=df)

# %%
sns.barplot(x="BldgType",y="SalePrice",data=df)

# %%
sns.barplot(x="SaleType",y="SalePrice",data=df)

# %%
sns.pairplot(data = df[["SalePrice","MoSold","SaleCondition"]],size=5,hue='SaleCondition')

# %%
# test_df = test_df.fillna(-1)

# %%
sns.barplot(x="Condition2",y="SalePrice",data=df)
df.Condition2.value_counts()
# Out:
# Norm      1446
# Feedr        6
# Artery       2
# RRNn         2
# PosN         2
# PosA         1
# RRAn         1
# RRAe         1
# dtype: int64

# %%
sns.pairplot(data = df[["SalePrice","YearRemodAdd"]],size=5)

# %%
sns.barplot(x="MasVnrType",y="SalePrice",data=df)
df.MasVnrType.value_counts()
# Out:
# None       864
# BrkFace    446
# Stone      128
# BrkCmn      15
# dtype: int64

# %%
sns.barplot(x="ExterQual",y="SalePrice",data=df)
df.ExterQual.value_counts()
# Out:
# TA    907
# Gd    488
# Ex     52
# Fa     14
# dtype: int64

# %%
sns.barplot(x="ExterCond",y="SalePrice",data=df)
df.ExterCond.value_counts()
# Out:
# TA    1283
# Gd     146
# Fa      28
# Ex       3
# Po       1
# dtype: int64

# %%
sns.barplot(x="CentralAir",y="SalePrice",data=df)
df.CentralAir.value_counts()
# Out:
# Y    1366
# N      95
# dtype: int64

# %%
sns.barplot(x="LowQualFinSF",y="SalePrice",data=df)
df.LowQualFinSF.value_counts()
# Out:
# 0      1435
# 80        3
# 360       2
# 528       1
# 53        1
# 120       1
# 144       1
# 156       1
# 205       1
# 232       1
# 234       1
# 371       1
# 572       1
# 390       1
# 392       1
# 397       1
# 420       1
# 473       1
# 479       1
# 481       1
# 513       1
# 514       1
# 515       1
# 384       1
# dtype: int64

# %%
sns.barplot(x="Heating",y="SalePrice",data=df)
df.Heating.value_counts()
# Out:
# GasA     1429
# GasW       18
# Grav        7
# Wall        4
# OthW        2
# Floor       1
# dtype: int64

# %%
sns.pairplot(data = df[["SalePrice","LowQualFinSF"]],size=5)

# %%
sns.barplot(x="BldgType",y="SalePrice",data=df)
df.BldgType.value_counts()
# Out:
# 1Fam      1221
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# dtype: int64

# %%
sns.barplot(x="Fireplaces",y="SalePrice",data=df)
df.MoSold.value_counts()
# Out:
# 6     253
# 7     234
# 5     204
# 4     141
# 8     122
# 3     107
# 10     89
# 11     79
# 9      63
# 12     59
# 1      58
# 2      52
# dtype: int64

# %%
sns.pairplot(data = df[["SalePrice","GrLivArea"]],size=5)

# %%
sns.barplot(x="ExterCond",y="SalePrice",data=df)
df.ExterCond.value_counts()
# Out:
# TA    1283
# Gd     146
# Fa      28
# Ex       3
# Po       1
# dtype: int64

# %%
sns.barplot(x="RoofMatl",y="SalePrice",data=df)
df.RoofMatl.value_counts()
# Out:
# CompShg    1435
# Tar&Grv      11
# WdShngl       6
# WdShake       5
# Membran       1
# Metal         1
# ClyTile       1
# Roll          1
# dtype: int64

# %%
sns.barplot(x="LandSlope",y="SalePrice",data=df)
df.LandSlope.value_counts()
# Out:
# Gtl    1383
# Mod      65
# Sev      13
# dtype: int64

# %%
sns.barplot(x="LandContour",y="SalePrice",data=df)
df.LandContour.value_counts()
# Out:
# Lvl    1312
# Bnk      63
# HLS      50
# Low      36
# dtype: int64

# %%
sns.barplot(x="Alley",y="SalePrice",data=df)
df.Alley.value_counts()
# Out:
# Grvl    50
# Pave    41
# dtype: int64

# %%
sns.barplot(x="Street",y="SalePrice",data=df)
df.Street.value_counts()
# Out:
# Pave    1455
# Grvl       6
# dtype: int64

# %%
# remove pool,utilities,year sold condition2 roofMatl LowQualFinSF
